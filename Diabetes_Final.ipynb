# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("diabetes_prediction_dataset.csv")

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
Gender: This likely indicates the gender of the individual, usually categorized as male or female.

Age: This represents the age of the individual, typically measured in years.

Hypertension: This binary feature likely indicates whether the individual has hypertension (high blood pressure) or not (1 for presence, 0 for absence).

Heart Disease: Similar to hypertension, this binary feature likely indicates whether the individual has heart disease or not.

Smoking History: This feature likely represents the individual's smoking habits, possibly categorized as smoker/non-smoker or with more detail.

BMI (Body Mass Index): BMI is a measure of body fat based on height and weight. It's calculated by dividing a person's weight in kilograms by the square of their height in meters.

HbA1c Level: HbA1c (hemoglobin A1c) is a measure of long-term blood sugar control. It represents the average blood sugar levels over the past 2-3 months.

Blood Glucose Level: This likely represents the individual's current blood glucose level, which is a measure of the amount of glucose in the blood.

Diabetes: This is the target variable and likely indicates whether the individual has diabetes or not (1 for presence, 0 for absence).
# Out:
#   Cell In[6], line 9
#     Smoking History: This feature likely represents the individual's smoking habits, possibly categorized as smoker/non-smoker or with more detail.
#                                                                   ^
# SyntaxError: unterminated string literal (detected at line 9)

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease           bmi   HbA1c_level  \
# count  96146.000000  96146.000000   96146.000000  96146.000000  96146.000000
# mean      41.794326      0.077601       0.040803     27.321461      5.532609
# std       22.462948      0.267544       0.197833      6.767716      1.073232
# min        0.080000      0.000000       0.000000     10.010000      3.500000
# 25%       24.000000      0.000000       0.000000     23.400000      4.800000
# 50%       43.000000      0.000000       0.000000     27.320000      5.800000
# 75%       59.000000      0.000000       0.000000     29.860000      6.200000
# max       80.000000      1.000000       1.000000     95.690000      9.000000
#
#        blood_glucose_level      diabetes
# count         96146.000000  96146.000000
# mean            138.218231      0.088220
# std              40.909771      0.283616
# min              80.000000      0.000000
# 25%             100.000000      0.000000
# ...

# %%
df['gender'].value_counts()
# Out:
# Female    56161
# Male      39967
# Other        18
# Name: gender, dtype: int64

# %%
df1=df[(df['gender']=='Female') | (df['gender']=='Male')]
df1
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df1['gender']=df1['gender'].replace({'Female':1,'Male':0})
# Out:
# C:\Users\Vishakha\AppData\Local\Temp\ipykernel_24036\926941482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender']=df1['gender'].replace({'Female':1,'Male':0})

# %%
df1
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0           1  80.0             0              1           never  25.19
# 1           1  54.0             0              0         No Info  27.32
# 2           0  28.0             0              0           never  27.32
# 3           1  36.0             0              0         current  23.45
# 4           0  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994       1  36.0             0              0         No Info  24.60
# 99996       1   2.0             0              0         No Info  17.37
# 99997       0  66.0             0              0          former  27.83
# 99998       1  24.0             0              0           never  35.42
# 99999       1  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df1["age"]
# Out:
# 0        80.0
# 1        54.0
# 2        28.0
# 3        36.0
# 4        76.0
#          ...
# 99994    36.0
# 99996     2.0
# 99997    66.0
# 99998    24.0
# 99999    57.0
# Name: age, Length: 96128, dtype: float64

# %%
plt.hist(df1["age"])
# Out:
# (array([ 8748.,  6957.,  9242.,  9881., 10204., 11230., 11711., 10499.,
#          7736.,  9920.]),
#  array([ 0.08 ,  8.072, 16.064, 24.056, 32.048, 40.04 , 48.032, 56.024,
#         64.016, 72.008, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
l_age=np.log(df1["age"])
plt.hist(l_age)
# Out:
# (array([3.6000e+01, 1.4600e+02, 3.3400e+02, 7.5100e+02, 1.9880e+03,
#         2.8760e+03, 4.1910e+03, 9.8830e+03, 2.4827e+04, 5.1096e+04]),
#  array([-2.52572864, -1.83495312, -1.14417759, -0.45340206,  0.23737347,
#          0.928149  ,  1.61892452,  2.30970005,  3.00047558,  3.69125111,
#          4.38202663]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import boxcox
b_age,lam=boxcox(df1['age']+0.0001)
plt.hist(b_age)
# Out:
# (array([ 5173.,  5149.,  6362.,  9459.,  9882., 11583., 13100., 12815.,
#         11048., 11557.]),
#  array([-1.08996824,  2.97552875,  7.04102573, 11.10652272, 15.1720197 ,
#         19.23751669, 23.30301367, 27.36851066, 31.43400764, 35.49950463,
#         39.56500162]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import yeojohnson
y_age,lam=yeojohnson(df1['age'])
plt.hist(y_age)
# Out:
# (array([ 6131.,  4995.,  7899.,  8318.,  9893., 11779., 13168., 12705.,
#          9683., 11557.]),
#  array([ 0.07941912,  4.32596488,  8.57251063, 12.81905639, 17.06560214,
#         21.3121479 , 25.55869365, 29.8052394 , 34.05178516, 38.29833091,
#         42.54487667]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df1['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27f811a5fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27fffe52a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27fff149910>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fffe4e310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fffe4f7d0>],
#  'means': []}

# %%
df1
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0           1  80.0             0              1           never  25.19
# 1           1  54.0             0              0         No Info  27.32
# 2           0  28.0             0              0           never  27.32
# 3           1  36.0             0              0         current  23.45
# 4           0  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994       1  36.0             0              0         No Info  24.60
# 99996       1   2.0             0              0         No Info  17.37
# 99997       0  66.0             0              0          former  27.83
# 99998       1  24.0             0              0           never  35.42
# 99999       1  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df1['hypertension'].value_counts()
# Out:
# 0    88667
# 1     7461
# Name: hypertension, dtype: int64

# %%
df1['heart_disease'].value_counts()
# Out:
# 0    92205
# 1     3923
# Name: heart_disease, dtype: int64

# %%
df1=pd.get_dummies(df1,columns=["smoking_history"],dtype=int)
df1
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0           1  80.0             0              1  25.19          6.6
# 1           1  54.0             0              0  27.32          6.6
# 2           0  28.0             0              0  27.32          5.7
# 3           1  36.0             0              0  23.45          5.0
# 4           0  76.0             1              1  20.14          4.8
# ...       ...   ...           ...            ...    ...          ...
# 99994       1  36.0             0              0  24.60          4.8
# 99996       1   2.0             0              0  17.37          6.5
# 99997       0  66.0             0              0  27.83          5.7
# 99998       1  24.0             0              0  35.42          4.0
# 99999       1  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  smoking_history_No Info  \
# 0                      140         0                        0
# ...

# %%
plt.hist(df1['bmi'])
# Out:
# (array([8.6520e+03, 3.1378e+04, 4.6526e+04, 7.3850e+03, 1.7160e+03,
#         3.7900e+02, 7.3000e+01, 8.0000e+00, 4.0000e+00, 7.0000e+00]),
#  array([10.01 , 18.578, 27.146, 35.714, 44.282, 52.85 , 61.418, 69.986,
#         78.554, 87.122, 95.69 ]),
#  <BarContainer object of 10 artists>)

# %%
df1['bmi']=np.log(df1["bmi"])
plt.hist(df1['bmi'])
# Out:
# (array([1.3300e+02, 2.5870e+03, 8.5980e+03, 1.8159e+04, 4.6285e+04,
#         1.4691e+04, 4.6500e+03, 9.2700e+02, 8.7000e+01, 1.1000e+01]),
#  array([2.30358459, 2.52933751, 2.75509043, 2.98084336, 3.20659628,
#         3.4323492 , 3.65810212, 3.88385504, 4.10960796, 4.33536088,
#         4.5611138 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df1['bmi'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27fff11b110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27fff0c44d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27fff11a990>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fff0c54d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fff0c5cd0>],
#  'means': []}

# %%
q1=df1['bmi'].quantile(0.25)
q3=df1['bmi'].quantile(0.75)
IQR=q3-q1
max1=q3+1.5*IQR
min1=q1-1.5*IQR
upper=df1['bmi']>=max1
lower=df1['bmi']<=min1
upper_in=[]
lower_in=[]
for i in upper.index:
    if upper[i]==True:
        upper_in.append(i)
for i in lower.index:
    if lower[i]==True:
        lower_in.append(i)

# %%
for i in upper_in:
    df1.drop(i,inplace=True)
for i in lower_in:
    df1.drop(i,inplace=True)

# %%
plt.boxplot(df1['bmi'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27fff71f4d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27fff6c48d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27fff169dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fff6c5ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fff6c62d0>],
#  'means': []}

# %%
df1
# Out:
#        gender   age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0           1  80.0             0              1  3.226447          6.6
# 1           1  54.0             0              0  3.307619          6.6
# 2           0  28.0             0              0  3.307619          5.7
# 3           1  36.0             0              0  3.154870          5.0
# 4           0  76.0             1              1  3.002708          4.8
# ...       ...   ...           ...            ...       ...          ...
# 99994       1  36.0             0              0  3.202746          4.8
# 99996       1   2.0             0              0  2.854745          6.5
# 99997       0  66.0             0              0  3.326115          5.7
# 99998       1  24.0             0              0  3.567277          4.0
# 99999       1  57.0             0              0  3.110399          6.6
#
#        blood_glucose_level  diabetes  smoking_history_No Info  \
# ...

# %%
plt.hist(df1["HbA1c_level"])
# Out:
# (array([13564.,  6807., 13518.,     0., 37112., 15709.,   559.,   577.,
#           595.,  1199.]),
#  array([3.5 , 4.05, 4.6 , 5.15, 5.7 , 6.25, 6.8 , 7.35, 7.9 , 8.45, 9.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df1["HbA1c_level"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27fffe31a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27fffe33150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27fff6b31d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fffe31e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fffe78510>],
#  'means': []}

# %%
q1=df1['HbA1c_level'].quantile(0.25)
q3=df1['HbA1c_level'].quantile(0.75)
IQR=q3-q1
max1=q3+1.5*IQR
min1=q1-1.5*IQR
upper=df1['HbA1c_level']>=max1
lower=df1['HbA1c_level']<=min1
upper_in=[]
lower_in=[]
for i in upper.index:
    if upper[i]==True:
        upper_in.append(i)
for i in lower.index:
    if lower[i]==True:
        lower_in.append(i)

# %%
for i in upper_in:
    df1.drop(i,inplace=True)
for i in lower_in:
    df1.drop(i,inplace=True)

# %%
plt.boxplot(df1["HbA1c_level"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27f80bbe110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27f80b88ad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27f80bbdad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27f80b89a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27f80b8a490>],
#  'means': []}

# %%
plt.hist(df1["blood_glucose_level"])
# Out:
# (array([25251.,     0., 27257., 26660.,     0.,  6737.,   457.,   511.,
#           499.,  1069.]),
#  array([ 80., 102., 124., 146., 168., 190., 212., 234., 256., 278., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df1["blood_glucose_level"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27fff281c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27fff283850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27fff2c6ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fff300910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fff301150>],
#  'means': []}

# %%
q1=df1['blood_glucose_level'].quantile(0.25)
q3=df1['blood_glucose_level'].quantile(0.75)
IQR=q3-q1
max1=q3+1.5*IQR
min1=q1-1.5*IQR
upper=df1['blood_glucose_level']>=max1
lower=df1['blood_glucose_level']<=min1
upper_in=[]
lower_in=[]
for i in upper.index:
    if upper[i]==True:
        upper_in.append(i)
for i in lower.index:
    if lower[i]==True:
        lower_in.append(i)

# %%
for i in upper_in:
    df1.drop(i,inplace=True)
for i in lower_in:
    df1.drop(i,inplace=True)

# %%
plt.boxplot(df1["blood_glucose_level"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27fff57c3d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27fff57c990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27fff4b3310>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fff57fbd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fff49c7d0>],
#  'means': []}

# %%
y=df1['diabetes']

# %%
del df1['diabetes']

# %%
x=df1

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(sampling_strategy=0.6,random_state=42)
x, y = ros.fit_resample(x, y)

# %%
y.value_counts()
# Out:
# 0    81941
# 1    49164
# Name: diabetes, dtype: int64

# %%
numerical_columns = ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x[numerical_columns])
x[numerical_columns] = scaler.transform(x[numerical_columns])

# %%
x
# Out:
#         gender       age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0            1  1.437311             0              1 -0.476923     0.719649
# 1            1  0.234603             0              0 -0.064110     0.719649
# 2            0 -0.968104             0              0 -0.064110    -0.132036
# 3            1 -0.598040             0              0 -0.840936    -0.794458
# 4            0  1.252279             1              1 -1.614782    -0.983721
# ...        ...       ...           ...            ...       ...          ...
# 131100       1  0.743441             0              0  1.252108    -0.037404
# 131101       1  1.206021             0              0 -0.888873     0.151859
# 131102       1  1.437311             0              0  0.066369     1.571335
# 131103       0  0.604667             0              0 -0.105229     1.098176
# 131104       0  1.437311             0              1  0.336654     1.098176
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,classification_report,f1_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
knn_model=KNeighborsClassifier(n_neighbors=9)
knn_model.fit(x_train,y_train)
y_test_pred=knn_model.predict(x_test)
print("confusion matrix")
print(confusion_matrix(y_test,y_test_pred))
print("accuracy")
print(accuracy_score(y_test,y_test_pred))
print("precision:")
print(precision_score(y_test,y_test_pred))
print("recall")
print(recall_score(y_test,y_test_pred))
print("classification report")
print(classification_report(y_test,y_test_pred))
print("f1_score")
print(f1_score(y_test,y_test_pred))
# Out:
# confusion matrix
# [[21827  2724]
#  [  487 14294]]
# accuracy
# 0.9183616393776061
# precision:
# 0.8399341873310612
# recall
# 0.9670522968676003
# classification report
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93     24551
#            1       0.84      0.97      0.90     14781
#
#     accuracy                           0.92     39332
#    macro avg       0.91      0.93      0.92     39332
# weighted avg       0.93      0.92      0.92     39332
#
# f1_score
# 0.8990219818233278

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,classification_report,f1_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
logistic_model=LogisticRegression()
logistic_model.fit(x_train,y_train)
y_test_pred=logistic_model.predict(x_test)
print("confusion matrix")
print(confusion_matrix(y_test,y_test_pred))
print("accuracy")
print(accuracy_score(y_test,y_test_pred))
print("precision:")
print(precision_score(y_test,y_test_pred))
print("recall")
print(recall_score(y_test,y_test_pred))
print("classification report")
print(classification_report(y_test,y_test_pred))
print("f1_score")
print(f1_score(y_test,y_test_pred))
# Out:
# confusion matrix
# [[21995  2556]
#  [ 3064 11717]]
# accuracy
# 0.8571138004678125
# precision:
# 0.8209206193512226
# recall
# 0.7927068533928692
# classification report
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     24551
#            1       0.82      0.79      0.81     14781
#
#     accuracy                           0.86     39332
#    macro avg       0.85      0.84      0.85     39332
# weighted avg       0.86      0.86      0.86     39332
#
# f1_score
# 0.8065670819852688

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,classification_report,f1_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
decision_tree_model=DecisionTreeClassifier()
decision_tree_model.fit(x_train,y_train)
y_test_pred=decision_tree_model.predict(x_test)
print("confusion matrix")
print(confusion_matrix(y_test,y_test_pred))
print("accuracy")
print(accuracy_score(y_test,y_test_pred))
print("precision:")
print(precision_score(y_test,y_test_pred))
print("recall")
print(recall_score(y_test,y_test_pred))
print("classification report")
print(classification_report(y_test,y_test_pred))
print("f1_score")
print(f1_score(y_test,y_test_pred))
# Out:
# confusion matrix
# [[23711   840]
#  [    3 14778]]
# accuracy
# 0.9785670700701719
# precision:
# 0.9462159047253169
# recall
# 0.9997970367363507
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     24551
#            1       0.95      1.00      0.97     14781
#
#     accuracy                           0.98     39332
#    macro avg       0.97      0.98      0.98     39332
# weighted avg       0.98      0.98      0.98     39332
#
# f1_score
# 0.9722688246323892

# %%
# random forest consists many dts 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,classification_report,f1_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
random_forest_model=RandomForestClassifier(n_estimators=10)
random_forest_model.fit(x_train,y_train)
y_test_pred=random_forest_model.predict(x_test)
print("confusion matrix:")
print(confusion_matrix(y_test,y_test_pred))
print("accuracy:")
print(accuracy_score(y_test,y_test_pred))
print("precision:")
print(precision_score(y_test,y_test_pred))
print("recall:")
print(recall_score(y_test,y_test_pred))
print("classification report")
print(classification_report(y_test,y_test_pred))
print("f1_score:")
# Out:
# confusion matrix:
# [[24072   479]
#  [    0 14781]]
# accuracy:
# 0.9878216210719007
# precision:
# 0.968610747051114
# recall:
# 1.0
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     24551
#            1       0.97      1.00      0.98     14781
#
#     accuracy                           0.99     39332
#    macro avg       0.98      0.99      0.99     39332
# weighted avg       0.99      0.99      0.99     39332
#
# f1_score:

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,classification_report,f1_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
gradient_boosting_model=GradientBoostingClassifier(learning_rate=0.1)
gradient_boosting_model.fit(x_train,y_train)
y_test_pred=gradient_boosting_model.predict(x_test)
print("confusion matrix:")
print(confusion_matrix(y_test,y_test_pred))
print("accuracy:")
print(accuracy_score(y_test,y_test_pred))
print("precision:")
print(precision_score(y_test,y_test_pred))
print("recall:")
print(recall_score(y_test,y_test_pred))
print("classification report")
print(classification_report(y_test,y_test_pred))
print("f1_score:")
print(f1_score(y_test,y_test_pred))
# Out:
# confusion matrix:
# [[22259  2292]
#  [ 1876 12905]]
# accuracy:
# 0.8940303061120716
# precision:
# 0.8491807593604
# recall:
# 0.8730803057979839
# classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91     24551
#            1       0.85      0.87      0.86     14781
#
#     accuracy                           0.89     39332
#    macro avg       0.89      0.89      0.89     39332
# weighted avg       0.89      0.89      0.89     39332
#
# f1_score:
# 0.8609647074521315
